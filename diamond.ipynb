# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
diamond = pd.read_csv('./input/data.csv')

# %%
diamond.shape
# Out:
# (40455, 10)

# %%
diamond.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   2.26      Ideal     G     SI2   61.9   57.0  8.44  8.36  5.20  12831
# 1   2.43  Very Good     H     SI2   63.2   57.0  8.56  8.50  5.39  16170
# 2   0.80    Premium     F     SI2   61.0   57.0  6.03  6.01  3.67   2797
# 3   0.40      Ideal     F      I1   63.3   60.0  4.68  4.64  2.95    630
# 4   0.31      Ideal     G     VS2   61.6   55.0  4.39  4.37  2.70    698

# %%
diamond.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
diamond.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
diamond.describe()
# Out:
#               carat         depth         table             x             y  \
# count  40455.000000  40455.000000  40455.000000  40455.000000  40455.000000
# mean       0.798385     61.747932     57.459085      5.732041      5.735939
# std        0.474353      1.432322      2.231152      1.123169      1.152802
# min        0.200000     43.000000     43.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.700000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        5.010000     79.000000     79.000000     10.740000     58.900000
#
#                   z         price
# count  40455.000000  40455.000000
# mean       3.539537   3939.242813
# std        0.709709   4000.344155
# min        0.000000    326.000000
# 25%        2.910000    950.000000
# 50%        3.530000   2409.000000
# 75%        4.040000   5331.000000
# max       31.800000  18823.000000

# %%
diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 10 columns):
# carat      40455 non-null float64
# cut        40455 non-null object
# color      40455 non-null object
# clarity    40455 non-null object
# depth      40455 non-null float64
# table      40455 non-null float64
# x          40455 non-null float64
# y          40455 non-null float64
# z          40455 non-null float64
# price      40455 non-null int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.1+ MB

# %%
diamond['carat'].unique()
# Out:
# array([2.26, 2.43, 0.8 , 0.4 , 0.31, 0.53, 0.7 , 1.13, 0.35, 1.01, 0.3 ,
#        1.23, 0.33, 0.51, 0.41, 1.57, 1.25, 1.08, 1.02, 0.74, 0.57, 0.26,
#        0.9 , 1.  , 0.32, 0.34, 0.38, 0.52, 1.52, 0.54, 1.15, 0.71, 0.91,
#        1.07, 1.22, 1.28, 0.58, 1.2 , 0.5 , 1.51, 1.21, 0.61, 1.8 , 0.84,
#        1.03, 1.34, 0.6 , 0.37, 0.72, 0.75, 1.73, 1.71, 0.23, 1.7 , 1.11,
#        1.09, 0.39, 0.43, 0.56, 1.53, 2.  , 0.79, 0.86, 1.3 , 0.27, 0.62,
#        1.5 , 0.25, 1.32, 1.36, 1.24, 1.18, 1.12, 0.73, 0.29, 2.01, 0.96,
#        1.75, 2.29, 0.42, 1.58, 2.05, 2.21, 1.06, 0.95, 0.76, 0.94, 1.56,
#        1.14, 0.81, 1.55, 0.78, 3.01, 3.02, 1.16, 0.59, 2.14, 0.36, 0.69,
#        1.79, 1.97, 2.04, 1.91, 0.92, 2.06, 0.77, 2.02, 1.59, 2.17, 0.49,
#        2.03, 1.1 , 1.31, 1.27, 0.28, 1.44, 0.97, 1.54, 1.05, 0.46, 0.24,
#        0.44, 1.04, 1.76, 2.15, 1.39, 1.47, 1.74, 1.6 , 2.48, 1.43, 0.82,
#        0.55, 0.83, 1.26, 1.33, 1.48, 1.64, 2.3 , 2.4 , 2.53, 2.11, 2.25,
#        0.93, 2.22, 2.09, 0.21, 2.27, 2.31, 1.37, 2.07, 2.08, 1.41, 1.19,
#        2.24, 2.18, 1.17, 2.12, 0.63, 1.61, 0.66, 1.72, 1.29, 2.16, 1.35,
#        1.45, 1.86, 0.47, 3.51, 2.2 , 1.63, 2.1 , 2.35, 1.62, 2.55, 2.28,
#        1.68, 0.64, 0.65, 2.13, 0.45, 4.01, 1.66, 0.48, 2.56, 1.49, 1.67,
#        2.44, 1.87, 2.38, 0.68, 1.38, 2.33, 2.52, 0.85, 1.81, 2.23, 0.87,
#        0.67, 2.5 , 2.45, 1.65, 1.46, 1.9 , 0.98, 1.4 , 2.19, 1.83, 2.41,
#        1.42, 2.49, 1.88, 2.39, 2.74, 0.89, 0.99, 1.89, 0.2 , 2.36, 3.  ,
#        1.77, 2.58, 2.34, 0.88, 1.99, 2.46, 2.51, 1.69, 2.54, 2.37, 2.57,
#        2.32, 1.78, 1.92, 1.96, 0.22, 2.65, 2.72, 2.47, 4.  , 3.5 , 2.8 ,
#        1.98, 1.84, 2.42, 3.05, 3.04, 2.71, 1.85, 2.77, 1.82, 2.64, 1.94,
#        2.68, 2.66, 1.93, 2.6 , 4.5 , 1.95, 2.75, 2.63, 3.67, 5.01])

# %%
corr = diamond.corr()
plt.figure(figsize = (8,6))
hm=sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            annot=True,fmt='.2f',linewidths=0.30, cmap = "coolwarm")
plt.title('Correlation of df Features', y = 1.05, size=15)
hm.set_ylim(7,0,0)
# Out:
# (7, 0)

# %%
d1 = diamond['clarity'].value_counts()
d2 = diamond['cut'].value_counts()
d3 = diamond['color'].value_counts()

fig, axs = plt.subplots(1, 3, figsize=(20,20))
axs[0].pie(d1, autopct='%1.1f%%', shadow=True, startangle=90)
axs[1].pie(d2, autopct='%1.1f%%', shadow=True, startangle=90)
axs[2].pie(d3, autopct='%1.1f%%', shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x11ee38190>,
#   <matplotlib.patches.Wedge at 0x11ee389d0>,
#   <matplotlib.patches.Wedge at 0x11ee45490>,
#   <matplotlib.patches.Wedge at 0x11ee45f90>,
#   <matplotlib.patches.Wedge at 0x11ee53c90>,
#   <matplotlib.patches.Wedge at 0x11ee5d790>,
#   <matplotlib.patches.Wedge at 0x11ee6a050>],
#  [Text(-0.673958139799957, 0.869356328439255, ''),
#   Text(-1.0447275324110605, -0.3443027490774599, ''),
#   Text(-0.13649351387548092, -1.0914987497335598, ''),
#   Text(0.8732928438506007, -0.6688494665313943, ''),
#   Text(1.072990723667682, 0.24226206249246823, ''),
#   Text(0.6592815670216539, 0.8805383667878832, ''),
#   Text(0.17985657340428024, 1.0851965780462407, '')],
#  [Text(-0.36761353079997655, 0.47419436096686635, '21.0%'),
#   Text(-0.5698513813151239, -0.18780149949679628, '18.2%'),
#   Text(-0.07445100756844412, -0.5953629544001234, '17.8%'),
#   Text(0.47634155119123667, -0.36482698174439687, '15.4%'),
#   Text(0.5852676674550991, 0.13214294317770992, '12.5%'),
#   Text(0.3596081274663566, 0.4802936546115726, '10.0%'),
#   Text(0.09810358549324376, 0.5919254062070404, '5.2%')])

# %%
#NO ME SALEEEEE
'''
d4 = diamond['carat'].value_counts()
d5 = diamond['depth'].value_counts()
d6 = diamond['table'].value_counts()
d7 = diamond['price'].value_counts()
d8 = diamond['x'].value_counts()
d9 = diamond['y'].value_counts()
d10 = diamond['z'].value_counts()



fig, axs = plt.subplots(4, 4)
axs[0].distplot(d4, bins=50)
axs[1].distplot(d5, bins=50)
axs[2].distplot(d6, bins=50)
axs[3].distplot(d7, bins=50)
axs[4].distplot(d8, bins=50)
axs[5].distplot(d9, bins=50)
axs[6].distplot(d10, bins=50)
'''
# Out:
# "\nd4 = diamond['carat'].value_counts()\nd5 = diamond['depth'].value_counts()\nd6 = diamond['table'].value_counts()\nd7 = diamond['price'].value_counts()\nd8 = diamond['x'].value_counts()\nd9 = diamond['y'].value_counts()\nd10 = diamond['z'].value_counts()\n\n\n\nfig, axs = plt.subplots(4, 4)\naxs[0].distplot(d4, bins=50)\naxs[1].distplot(d5, bins=50)\naxs[2].distplot(d6, bins=50)\naxs[3].distplot(d7, bins=50)\naxs[4].distplot(d8, bins=50)\naxs[5].distplot(d9, bins=50)\naxs[6].distplot(d10, bins=50)\n"

# %%
diamond['clarity'].unique()
# Out:
# array(['SI2', 'I1', 'VS2', 'SI1', 'VS1', 'VVS2', 'IF', 'VVS1'],
#       dtype=object)

# %%
# To categorical
numeric_cut = {'Ideal': 1, 'Premium': 2, 'Very Good': 3, 'Good': 4, 'Fair': 5}
numeric_color = {'D': 1, 'E': 2, 'F': 3, 'G': 4, 'H': 5, 'I': 6, 'J': 7}
numeric_clarity = {'I1': 8 , 'SI2': 7, 'SI1': 6, 'VS2': 5, 'VS1': 4, 'VVS2':3 , 'VVS1': 2, 'IF':1}
diamond.replace({'cut': numeric_cut, 'color': numeric_color, 'clarity': numeric_clarity}, inplace=True)

# %%
diamond.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   2.26    1      4        7   61.9   57.0  8.44  8.36  5.20  12831
# 1   2.43    3      5        7   63.2   57.0  8.56  8.50  5.39  16170
# 2   0.80    2      3        7   61.0   57.0  6.03  6.01  3.67   2797
# 3   0.40    1      3        8   63.3   60.0  4.68  4.64  2.95    630
# 4   0.31    1      4        5   61.6   55.0  4.39  4.37  2.70    698

# %%
corr = diamond.corr()
plt.figure(figsize = (8,6))
hm=sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            annot=True,fmt='.2f',linewidths=0.30, cmap = "coolwarm")
plt.title('Correlation of df Features', y = 1.05, size=15)
hm.set_ylim(10,0,0)
# Out:
# (10, 0)

# %%
# STANDARD SCALER. Normalized the data by subtracting the mean from each data point and dividing by the std deviation.
columns = ['depth', 'table', 'x', 'y', 'z']
for col in columns:
    diamond[col] = (diamond[col] - np.mean(diamond[col])) / np.std(diamond[col]) 

diamond.head()
# Out:
#    carat  cut  color  clarity     depth     table         x         y  \
# 0   2.26    1      4        7  0.106170 -0.205764  2.411028  2.276274
# 1   2.43    3      5        7  1.013798 -0.205764  2.517870  2.397719
# 2   0.80    2      3        7 -0.522188 -0.205764  0.265287  0.237737
# 3   0.40    1      3        8  1.083616  1.138849 -0.936684 -0.950686
# 4   0.31    1      4        5 -0.103283 -1.102173 -1.194885 -1.184901
#
#           z  price
# 0  2.339667  12831
# 1  2.607386  16170
# 2  0.183828   2797
# 3 -0.830684    630
# 4 -1.182945    698

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,10))
axs[0].plot(diamond['depth'])
axs[1].plot(diamond['table'])

# %%
diamond.shape
# Out:
# (40455, 10)

# %%
diamond = diamond[(diamond['depth']>=-5 ) & (diamond['depth']<=5)]
diamond = diamond[(diamond['table']>=-5 ) & (diamond['table']<=6)]

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,10))
axs[0].plot(diamond['depth'])
axs[1].plot(diamond['table'])

# %%
diamond.shape
# Out:
# (40403, 10)

# %%
corr = diamond.corr()
plt.figure(figsize = (8,6))
hm=sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            annot=True,fmt='.2f',linewidths=0.30, cmap = "coolwarm")
plt.title('Correlation of df Features', y = 1.05, size=15)
hm.set_ylim(10,0,0)
# Out:
# (10, 0)

# %%
# i showed that there is a very strong positive correlation between x, y, z, carat and price.
diamond.drop(columns=['x', 'y', 'z'], inplace=True)

# %%
corr = diamond.corr()
plt.figure(figsize = (8,6))
hm=sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            annot=True,fmt='.2f',linewidths=0.30, cmap = "coolwarm")
plt.title('Correlation of df Features', y = 1.05, size=15)
hm.set_ylim(7,0,0)
# Out:
# (7, 0)

# %%
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
y = diamond["price"]
X = diamond[["carat", "cut", "color", "clarity", "depth", "table"]]
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
y_train
# Out:
# 23296    2089
# 9802     5234
# 33326    2376
# 29470    6209
# 21986     523
#          ...
# 20488    3704
# 22586    2543
# 17388    4580
# 33483    2704
# 1022     6788
# Name: price, Length: 32322, dtype: int64

# %%
models = {
    #"svm": LinearSVC(),
    #"logistic": LogisticRegression(solver='lbfgs', max_iter=2000),
    "forest": RandomForestRegressor(),
    "ridge": Ridge(),
    "svr": SVR(C=1.0, epsilon=0.2),
    "MLPClassifier": MLPClassifier(solver='lbfgs', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=1)
}

for modelName, model in models.items():
    print(f"Training model: {modelName}")
    model.fit(X_train, y_train)
    print(f"Training finished: {modelName}")
# Out:
# Training model: forest
# /usr/local/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Training finished: forest
# Training model: ridge
# Training finished: ridge
# Training model: svr
# /usr/local/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Training finished: svr
# Training model: MLPClassifier
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/Cellar/ipython/7.8.0/libexec/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3325                 else:
# -> 3326                     exec(code_obj, self.user_global_ns, self.user_ns)
#    3327             finally:
#
# <ipython-input-155-1df52d82ee55> in <module>
#      11     print(f"Training model: {modelName}")
# ---> 12     model.fit(X_train, y_train)
#      13     print(f"Training finished: {modelName}")
#
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py in fit(self, X, y)
#     981         return self._fit(X, y, incremental=(self.warm_start and
# --> 982                                             hasattr(self, "classes_")))
#     983
#
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py in _fit(self, X, y, incremental)
#     374             self._fit_lbfgs(X, y, activations, deltas, coef_grads,
# --> 375                             intercept_grads, layer_units)
#     376         return self
#
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py in _fit_lbfgs(self, X, y, activations, deltas, coef_grads, intercept_grads, layer_units)
#     464             pgtol=self.tol,
# --> 465             args=(X, y, activations, deltas, coef_grads, intercept_grads))
#     466
#
# /usr/local/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#
# /usr/local/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#
# /usr/local/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     284         def func_and_grad(x):
# --> 285             f = fun(x, *args)
#     286             g = jac(x, *args)
#
# /usr/local/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#
# /usr/local/lib/python3.7/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      64         self.x = numpy.asarray(x).copy()
# ---> 65         fg = self.fun(x, *args)
#      66         self.jac = fg[1]
#
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py in _loss_grad_lbfgs(self, packed_coef_inter, X, y, activations, deltas, coef_grads, intercept_grads)
#     173         loss, coef_grads, intercept_grads = self._backprop(
# --> 174             X, y, activations, deltas, coef_grads, intercept_grads)
#     175         self.n_iter_ += 1
#
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py in _backprop(self, X, y, activations, deltas, coef_grads, intercept_grads)
#     218         # Forward propagate
# --> 219         activations = self._forward_pass(activations)
#     220
#
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py in _forward_pass(self, activations)
#     109         output_activation = ACTIVATIONS[self.out_activation_]
# --> 110         activations[i + 1] = output_activation(activations[i + 1])
#     111
#
# /usr/local/lib/python3.7/site-packages/sklearn/neural_network/_base.py in softmax(X)
#      92     tmp = X - X.max(axis=1)[:, np.newaxis]
# ---> 93     np.exp(tmp, out=X)
#      94     X /= X.sum(axis=1)[:, np.newaxis]
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/Cellar/ipython/7.8.0/libexec/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2017             try:
# -> 2018                 etype, value, tb = self._get_exc_info(exc_tuple)
#    2019             except ValueError:
#
# /usr/local/Cellar/ipython/7.8.0/libexec/lib/python3.7/site-packages/IPython/core/interactiveshell.py in _get_exc_info(self, exc_tuple)
#    1982         sys.last_value = value
# -> 1983         sys.last_traceback = tb
#    1984
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/Cellar/ipython/7.8.0/libexec/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_code(self, code_obj, result, async_)
#    3341             if result is not None:
#    3342                 result.error_in_exec = sys.exc_info()[1]
# -> 3343             self.showtraceback(running_compiled_code=True)
#    3344         else:
#    3345             outflag = False
#
# /usr/local/Cellar/ipython/7.8.0/libexec/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2053
#    2054         except KeyboardInterrupt:
# -> 2055             print('\n' + self.get_exception_only(), file=sys.stderr)
#    2056
#    2057     def _showtraceback(self, etype, evalue, stb):
#
# /usr/local/Cellar/ipython/7.8.0/libexec/lib/python3.7/site-packages/IPython/core/interactiveshell.py in get_exception_only(self, exc_tuple)
#    1998         """
#    1999         etype, value, tb = self._get_exc_info(exc_tuple)
# -> 2000         msg = traceback.format_exception_only(etype, value)
#    2001         return ''.join(msg)
#    2002
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/traceback.py in format_exception_only(etype, value)
#     138
#     139     """
# --> 140     return list(TracebackException(etype, value, None).format_exception_only())
#     141
#     142
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/traceback.py in __init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     495                 lookup_lines=False,
#     496                 capture_locals=capture_locals,
# --> 497                 _seen=_seen)
#     498         else:
#     499             context = None
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/traceback.py in __init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, _seen)
#     506         self.stack = StackSummary.extract(
#     507             walk_tb(exc_traceback), limit=limit, lookup_lines=lookup_lines,
# --> 508             capture_locals=capture_locals)
#     509         self.exc_type = exc_type
#     510         # Capture now to permit freeing resources: only complication is in the
#
# /usr/local/Cellar/python/3.7.4_1/Frameworks/Python.framework/Versions/3.7/lib/python3.7/traceback.py in extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     357                 filename, lineno, name, lookup_line=False, locals=f_locals))
#     358         for filename in fnames:
# --> 359             linecache.checkcache(filename)
#     360         # If immediate lookup was desired, trigger lookups now.
#     361         if lookup_lines:
#
# /usr/local/Cellar/ipython/7.8.0/libexec/lib/python3.7/site-packages/IPython/core/compilerop.py in check_linecache_ipython(*args)
#     158     # Then, update back the cache with our data, so that tracebacks related
#     159     # to our compiled codes can be produced.
# --> 160     linecache.cache.update(linecache._ipython_cache)
#
# KeyboardInterrupt:

# %%
d = {modelName:model.predict(X_test) for modelName, model in models.items()}

df = pd.DataFrame(d)
df["gt"] = y_test.reset_index(drop=True)
df.head()
# Out:
#    forest        ridge          svr    gt
# 0  1145.5  -479.427201  2949.159205   924
# 1  1273.2   820.084743  2646.308880  1267
# 2  5618.9  5923.229454  3489.183616  5521
# 3   909.4   315.614926  2063.240909   721
# 4  1076.0  1354.061561  1608.255429  1007

# %%
kf = KFold(n_splits=2, shuffle=True, random_state=11)
for k, v in models.items():
    scores = cross_val_score(v, X_train, y_train, scoring='r2', cv=kf, n_jobs=2)
    name = str(v)
    print(f'{name}: Average R-Squared Score:', np.mean(scores))
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False): Average R-Squared Score: 0.978049546038804
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001): Average R-Squared Score: 0.9060896221831642
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.2,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False): Average R-Squared Score: -0.05315133583356346

# %%
'''
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from IPython.core.display import display, HTML

switchColor = lambda value: f"<b style=\"color:orange\">{round(value,2)}</b>" if value < 0.8 else f"<b style=\"color:green\">{round(value,2)}</b>"
printBonito = lambda label,val: display(HTML(f"<span style=\"padding-left:20px\">The {label} is: {switchColor(val)}</span>"))

for modelName, model in models.items():    
    print(f"Evaluating model [{modelName}]:")
    printBonito("Accuracy", accuracy_score(df["gt"],df[modelName]))
    printBonito("Precision", precision_score(df["gt"],df[modelName],average='weighted'))
    printBonito("Recall", recall_score(df["gt"],df[modelName],average='weighted'))    
'''
# Out:
# '\nfrom sklearn.metrics import accuracy_score\nfrom sklearn.metrics import precision_score\nfrom sklearn.metrics import recall_score\nfrom IPython.core.display import display, HTML\n\nswitchColor = lambda value: f"<b style="color:orange">{round(value,2)}</b>" if value < 0.8 else f"<b style="color:green">{round(value,2)}</b>"\nprintBonito = lambda label,val: display(HTML(f"<span style="padding-left:20px">The {label} is: {switchColor(val)}</span>"))\n\nfor modelName, model in models.items():    \n    print(f"Evaluating model [{modelName}]:")\n    printBonito("Accuracy", accuracy_score(df["gt"],df[modelName]))\n    printBonito("Precision", precision_score(df["gt"],df[modelName],average=\'weighted\'))\n    printBonito("Recall", recall_score(df["gt"],df[modelName],average=\'weighted\'))\n    \n'

# %% [markdown]
# ## CAMBIANDO EL TEST

# %%
test_diamond = pd.read_csv('./input/test.csv')

# %%
test_diamond.head()
# Out:
#    id  carat      cut color clarity  depth  table     x     y     z
# 0   0   0.56    Ideal     I     VS2   62.1   54.0  5.30  5.33  3.30
# 1   1   1.05    Ideal     G     VS2   61.9   56.0  6.56  6.52  4.05
# 2   2   0.50  Premium     E     VS2   61.5   56.0  5.11  5.07  3.13
# 3   3   0.80    Ideal     F     VS1   62.8   56.0  5.91  5.96  3.73
# 4   4   0.54    Ideal     G     VS1   61.4   57.0  5.23  5.20  3.20

# %%
# To categorical
numeric_cut = {'Ideal': 1, 'Premium': 2, 'Very Good': 3, 'Good': 4, 'Fair': 5}
numeric_color = {'D': 1, 'E': 2, 'F': 3, 'G': 4, 'H': 5, 'I': 6, 'J': 7}
numeric_clarity = {'I1': 8 , 'SI2': 7, 'SI1': 6, 'VS2': 5, 'VS1': 4, 'VVS2':3 , 'VVS1': 2, 'IF':1}
test_diamond.replace({'cut': numeric_cut, 'color': numeric_color, 'clarity': numeric_clarity}, inplace=True)

# %%
test_diamond.head()
# Out:
#    id  carat  cut  color  clarity  depth  table     x     y     z
# 0   0   0.56    1      6        5   62.1   54.0  5.30  5.33  3.30
# 1   1   1.05    1      4        5   61.9   56.0  6.56  6.52  4.05
# 2   2   0.50    2      2        5   61.5   56.0  5.11  5.07  3.13
# 3   3   0.80    1      3        4   62.8   56.0  5.91  5.96  3.73
# 4   4   0.54    1      4        4   61.4   57.0  5.23  5.20  3.20

# %%
columns = ['depth', 'table', 'x', 'y', 'z']
for col in columns:
    test_diamond[col] = (test_diamond[col] - np.mean(test_diamond[col])) / np.std(test_diamond[col]) 

test_diamond.head()
# Out:
#    id  carat  cut  color  clarity     depth     table         x         y  \
# 0   0   0.56    1      6        5  0.241489 -1.537773 -0.383443 -0.360777
# 1   1   1.05    1      4        5  0.101972 -0.646693  0.744052  0.711770
# 2   2   0.50    2      2        5 -0.177064 -0.646693 -0.553462 -0.595116
# 3   3   0.80    1      3        4  0.729801 -0.646693  0.162408  0.207042
# 4   4   0.54    1      4        4 -0.246823 -0.201152 -0.446082 -0.477947
#
#           z
# 0 -0.340759
# 1  0.740676
# 2 -0.585884
# 3  0.279264
# 4 -0.484950

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,10))
axs[0].plot(test_diamond['depth'])
axs[1].plot(test_diamond['table'])

# %%
test_diamond.drop(columns=['x', 'y', 'z'], inplace=True)

# %%
test_diamond.head(10)
# Out:
#    id  carat  cut  color  clarity     depth     table
# 0   0   0.56    1      6        5  0.241489 -1.537773
# 1   1   1.05    1      4        5  0.101972 -0.646693
# 2   2   0.50    2      2        5 -0.177064 -0.646693
# 3   3   0.80    1      3        4  0.729801 -0.646693
# 4   4   0.54    1      4        4 -0.246823 -0.201152
# 5   5   2.25    1      2        8 -0.246823 -1.537773
# 6   6   0.33    3      4        3  0.729801 -0.201152
# 7   7   0.32    2      5        1  0.032213  0.244388
# 8   8   0.30    2      4        4 -0.246823  1.135469
# 9   9   2.10    1      6        7  0.869319 -0.646693

# %%
d1 = {modelName:model.predict(test_diamond[["carat", "cut", "color", "clarity", "depth", "table"]]) for modelName, model in models.items()}

df1 = pd.DataFrame(d1)
df1['id']=test_diamond['id']
new = df1[['id','forest']]
new.rename(columns={"forest": "price"}, inplace=True)
new.head()
# Out:
#    id        price
# 0   0  1291.800000
# 1   1  6564.488889
# 2   2  1605.700000
# 3   3  4201.340000
# 4   4  1867.900000

# %%
new

# %%
new.to_csv('prueba1.csv', index=False)
