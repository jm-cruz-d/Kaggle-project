# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
diamond = pd.read_csv('./input/data.csv')

# %%
diamond.shape
# Out:
# (40455, 10)

# %%
diamond.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   2.26      Ideal     G     SI2   61.9   57.0  8.44  8.36  5.20  12831
# 1   2.43  Very Good     H     SI2   63.2   57.0  8.56  8.50  5.39  16170
# 2   0.80    Premium     F     SI2   61.0   57.0  6.03  6.01  3.67   2797
# 3   0.40      Ideal     F      I1   63.3   60.0  4.68  4.64  2.95    630
# 4   0.31      Ideal     G     VS2   61.6   55.0  4.39  4.37  2.70    698

# %%
diamond.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
diamond.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %%
diamond.describe()
# Out:
#               carat         depth         table             x             y  \
# count  40455.000000  40455.000000  40455.000000  40455.000000  40455.000000
# mean       0.798385     61.747932     57.459085      5.732041      5.735939
# std        0.474353      1.432322      2.231152      1.123169      1.152802
# min        0.200000     43.000000     43.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.710000      4.720000
# 50%        0.700000     61.800000     57.000000      5.700000      5.710000
# 75%        1.040000     62.500000     59.000000      6.540000      6.540000
# max        5.010000     79.000000     79.000000     10.740000     58.900000
#
#                   z         price
# count  40455.000000  40455.000000
# mean       3.539537   3939.242813
# std        0.709709   4000.344155
# min        0.000000    326.000000
# 25%        2.910000    950.000000
# 50%        3.530000   2409.000000
# 75%        4.040000   5331.000000
# max       31.800000  18823.000000

# %%
diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 10 columns):
# carat      40455 non-null float64
# cut        40455 non-null object
# color      40455 non-null object
# clarity    40455 non-null object
# depth      40455 non-null float64
# table      40455 non-null float64
# x          40455 non-null float64
# y          40455 non-null float64
# z          40455 non-null float64
# price      40455 non-null int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 3.1+ MB

# %%
diamond['carat'].unique()
# Out:
# array([2.26, 2.43, 0.8 , 0.4 , 0.31, 0.53, 0.7 , 1.13, 0.35, 1.01, 0.3 ,
#        1.23, 0.33, 0.51, 0.41, 1.57, 1.25, 1.08, 1.02, 0.74, 0.57, 0.26,
#        0.9 , 1.  , 0.32, 0.34, 0.38, 0.52, 1.52, 0.54, 1.15, 0.71, 0.91,
#        1.07, 1.22, 1.28, 0.58, 1.2 , 0.5 , 1.51, 1.21, 0.61, 1.8 , 0.84,
#        1.03, 1.34, 0.6 , 0.37, 0.72, 0.75, 1.73, 1.71, 0.23, 1.7 , 1.11,
#        1.09, 0.39, 0.43, 0.56, 1.53, 2.  , 0.79, 0.86, 1.3 , 0.27, 0.62,
#        1.5 , 0.25, 1.32, 1.36, 1.24, 1.18, 1.12, 0.73, 0.29, 2.01, 0.96,
#        1.75, 2.29, 0.42, 1.58, 2.05, 2.21, 1.06, 0.95, 0.76, 0.94, 1.56,
#        1.14, 0.81, 1.55, 0.78, 3.01, 3.02, 1.16, 0.59, 2.14, 0.36, 0.69,
#        1.79, 1.97, 2.04, 1.91, 0.92, 2.06, 0.77, 2.02, 1.59, 2.17, 0.49,
#        2.03, 1.1 , 1.31, 1.27, 0.28, 1.44, 0.97, 1.54, 1.05, 0.46, 0.24,
#        0.44, 1.04, 1.76, 2.15, 1.39, 1.47, 1.74, 1.6 , 2.48, 1.43, 0.82,
#        0.55, 0.83, 1.26, 1.33, 1.48, 1.64, 2.3 , 2.4 , 2.53, 2.11, 2.25,
#        0.93, 2.22, 2.09, 0.21, 2.27, 2.31, 1.37, 2.07, 2.08, 1.41, 1.19,
#        2.24, 2.18, 1.17, 2.12, 0.63, 1.61, 0.66, 1.72, 1.29, 2.16, 1.35,
#        1.45, 1.86, 0.47, 3.51, 2.2 , 1.63, 2.1 , 2.35, 1.62, 2.55, 2.28,
#        1.68, 0.64, 0.65, 2.13, 0.45, 4.01, 1.66, 0.48, 2.56, 1.49, 1.67,
#        2.44, 1.87, 2.38, 0.68, 1.38, 2.33, 2.52, 0.85, 1.81, 2.23, 0.87,
#        0.67, 2.5 , 2.45, 1.65, 1.46, 1.9 , 0.98, 1.4 , 2.19, 1.83, 2.41,
#        1.42, 2.49, 1.88, 2.39, 2.74, 0.89, 0.99, 1.89, 0.2 , 2.36, 3.  ,
#        1.77, 2.58, 2.34, 0.88, 1.99, 2.46, 2.51, 1.69, 2.54, 2.37, 2.57,
#        2.32, 1.78, 1.92, 1.96, 0.22, 2.65, 2.72, 2.47, 4.  , 3.5 , 2.8 ,
#        1.98, 1.84, 2.42, 3.05, 3.04, 2.71, 1.85, 2.77, 1.82, 2.64, 1.94,
#        2.68, 2.66, 1.93, 2.6 , 4.5 , 1.95, 2.75, 2.63, 3.67, 5.01])

# %%
corr = diamond.corr()
plt.figure(figsize = (8,6))
hm=sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            annot=True,fmt='.2f',linewidths=0.30, cmap = "coolwarm")
plt.title('Correlation of df Features', y = 1.05, size=15)
hm.set_ylim(7,0,0)
# Out:
# (7, 0)

# %%
d1 = diamond['clarity'].value_counts()
d2 = diamond['cut'].value_counts()
d3 = diamond['color'].value_counts()

fig, axs = plt.subplots(1, 3, figsize=(20,20))
axs[0].pie(d1, autopct='%1.1f%%', shadow=True, startangle=90)
axs[1].pie(d2, autopct='%1.1f%%', shadow=True, startangle=90)
axs[2].pie(d3, autopct='%1.1f%%', shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x122178890>,
#   <matplotlib.patches.Wedge at 0x122185350>,
#   <matplotlib.patches.Wedge at 0x122185dd0>,
#   <matplotlib.patches.Wedge at 0x122190910>,
#   <matplotlib.patches.Wedge at 0x12219d610>,
#   <matplotlib.patches.Wedge at 0x1221a8110>,
#   <matplotlib.patches.Wedge at 0x1221a8990>],
#  [Text(-0.673958139799957, 0.869356328439255, ''),
#   Text(-1.0447275324110605, -0.3443027490774599, ''),
#   Text(-0.13649351387548092, -1.0914987497335598, ''),
#   Text(0.8732928438506007, -0.6688494665313943, ''),
#   Text(1.072990723667682, 0.24226206249246823, ''),
#   Text(0.6592815670216539, 0.8805383667878832, ''),
#   Text(0.17985657340428024, 1.0851965780462407, '')],
#  [Text(-0.36761353079997655, 0.47419436096686635, '21.0%'),
#   Text(-0.5698513813151239, -0.18780149949679628, '18.2%'),
#   Text(-0.07445100756844412, -0.5953629544001234, '17.8%'),
#   Text(0.47634155119123667, -0.36482698174439687, '15.4%'),
#   Text(0.5852676674550991, 0.13214294317770992, '12.5%'),
#   Text(0.3596081274663566, 0.4802936546115726, '10.0%'),
#   Text(0.09810358549324376, 0.5919254062070404, '5.2%')])

# %%
#NO ME SALEEEEE
d4 = diamond['carat'].value_counts()
d5 = diamond['depth'].value_counts()
d6 = diamond['table'].value_counts()
d7 = diamond['price'].value_counts()
d8 = diamond['x'].value_counts()
d9 = diamond['y'].value_counts()
d10 = diamond['z'].value_counts()



fig, axs = plt.subplots(4, 4)
axs[0].distplot(d4, bins=50)
axs[1].distplot(d5, bins=50)
axs[2].distplot(d6, bins=50)
axs[3].distplot(d7, bins=50)
axs[4].distplot(d8, bins=50)
axs[5].distplot(d9, bins=50)
axs[6].distplot(d10, bins=50)

# %%
diamond['clarity'].unique()
# Out:
# array(['SI2', 'I1', 'VS2', 'SI1', 'VS1', 'VVS2', 'IF', 'VVS1'],
#       dtype=object)

# %%
# To categorical
numeric_cut = {'Ideal': 1, 'Premium': 2, 'Very Good': 3, 'Good': 4, 'Fair': 5}
numeric_color = {'D': 1, 'E': 2, 'F': 3, 'G': 4, 'H': 5, 'I': 6, 'J': 7}
numeric_clarity = {'I1': 8 , 'SI2': 7, 'SI1': 6, 'VS2': 5, 'VS1': 4, 'VVS2':3 , 'VVS1': 2, 'IF':1}
diamond.replace({'cut': numeric_cut, 'color': numeric_color, 'clarity': numeric_clarity}, inplace=True)

# %%
diamond.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   2.26    1      4        7   61.9   57.0  8.44  8.36  5.20  12831
# 1   2.43    3      5        7   63.2   57.0  8.56  8.50  5.39  16170
# 2   0.80    2      3        7   61.0   57.0  6.03  6.01  3.67   2797
# 3   0.40    1      3        8   63.3   60.0  4.68  4.64  2.95    630
# 4   0.31    1      4        5   61.6   55.0  4.39  4.37  2.70    698

# %%
corr = diamond.corr()
plt.figure(figsize = (8,6))
hm=sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            annot=True,fmt='.2f',linewidths=0.30, cmap = "coolwarm")
plt.title('Correlation of df Features', y = 1.05, size=15)
hm.set_ylim(10,0,0)
# Out:
# (10, 0)

# %%
# STANDARD SCALER. Normalized the data by subtracting the mean from each data point and dividing by the std deviation.
columns = ['depth', 'table', 'x', 'y', 'z']
for col in columns:
    diamond[col] = (diamond[col] - np.mean(diamond[col])) / np.std(diamond[col]) 

diamond.head()
# Out:
#    carat  cut  color  clarity     depth     table         x         y  \
# 0   2.26    1      4        7  0.106170 -0.205764  2.411028  2.276274
# 1   2.43    3      5        7  1.013798 -0.205764  2.517870  2.397719
# 2   0.80    2      3        7 -0.522188 -0.205764  0.265287  0.237737
# 3   0.40    1      3        8  1.083616  1.138849 -0.936684 -0.950686
# 4   0.31    1      4        5 -0.103283 -1.102173 -1.194885 -1.184901
#
#           z  price
# 0  2.339667  12831
# 1  2.607386  16170
# 2  0.183828   2797
# 3 -0.830684    630
# 4 -1.182945    698

# %%
fig, axs = plt.subplots(1, 2, figsize=(10,10))
axs[0].plot(diamond['depth'])
axs[1].plot(diamond['table'])

# %%
corr = diamond.corr()
plt.figure(figsize = (8,6))
hm=sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            annot=True,fmt='.2f',linewidths=0.30, cmap = "coolwarm")
plt.title('Correlation of df Features', y = 1.05, size=15)
hm.set_ylim(10,0,0)
# Out:
# (10, 0)

# %%
# we showed that there is a very strong positive correlation between x, y, z, carat and price.
diamond.drop(columns=['x', 'y', 'z'], inplace=True)

# %%
corr = diamond.corr()
plt.figure(figsize = (8,6))
hm=sns.heatmap(corr,
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            annot=True,fmt='.2f',linewidths=0.30, cmap = "coolwarm")
plt.title('Correlation of df Features', y = 1.05, size=15)
hm.set_ylim(7,0,0)
# Out:
# (7, 0)

# %%
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# %%
y = diamond["price"]
X = diamond[["carat", "cut", "color", "clarity", "depth", "table"]]
steps = [
    StandardScaler(),
    Normalizer(),
#    PCA(n_components=3)
]

pipe = make_pipeline(*steps)

X = pipe.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
clf = LogisticRegression().fit(X, y)
scores = pd.DataFrame({
    "predicted":pred,
    "gt":y_test
})
scores["diff"] = np.abs(scores["predicted"]-scores["gt"])
scores["diff"].sum()/ len(y_test)
